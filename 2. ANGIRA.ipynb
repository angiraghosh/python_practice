# %% [markdown]
# Section 1: Comment

# %%
'''this
is
multiline
comment'''

# %%
a =99.01
b =100.10
print(a+b)

# %%
name = "moumita"
age =33
height =158
print(age,name,height)

# %%
a = "taki"
b = "barasat"
c = "kolkata"
print(a+b+c)

# %%
a ="digha"
b ="uk"
c = "kashmir"
print(a+" "+b+" "+c)

# %%
a = "kolkata is my city ,i am a student"
b = "i know kolkata very well because my home town is there"
c = "somebody knoe me very well because they are my family member"
print(a+" "+b+" "+c)

# %%
a = 25
b = 10.22
c = "nandita"
print(type(a+b+c))

# %%
a = "blue" 
#but my pen is pink colour
b = "red"
#rose are red
c ="i love both colours"
print(c+" "+b+" "+a)

# %%
a = age=20
print(a)

# %%
a = "good"
b ="morning"
print(a+" "+b)

# %%
a = "royal"
b = "sona"
print(b+" " +a)

# %%
a="india is my country"
b='i love my country'
print(a+" and "+b)

# %%
a="shan love mani"
b="but mani love shan more than him"
c="which one is right"
print(a+ " " +b+" ....tell me........ "+c)

# %%
a=10000
b=20000000
c=32567899
d=4356906532345
print(a+b+d)
print(a+b+c-d)

# %%
name = "Python"
print(name[0]) 
#Access Characters.

# %%
name = "Programming"
print(name[0:5])  

#string slicing

# %%
name = "python"
print(name.upper())
#UPPERCASE
print(name.lower())

# %%
a=2
b=5
sum= a+b
print(a+b) #if we wanr to direct sum
print(sum) #or we can do it this process

# %%
#ARITHEMATIC OPEARATORS
a=10
b=12
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)
print(a**b)

# %%
#RELATIONAL OPERATOR
a=10
b=12
print(a==b)
print(a!=b)
print(a<b)
print(a>b)
print(a<=b)
print(a>=b)

# %%
#assignemt operators
num=50
num+=50
print (num)
num-=70
print(num)
num%=60
print(num)

# %%
#logical operators
print(not False)
print(not True)
print (True and False)
print(True or False)

# %%
#TYPE CONVERTION
a=10
b=20.50
print(a+b)#automatically convet

# %%
#type casting
a="20"
b=30.55
print(int(a)+b)

# %%
#input in python
a=input("enter ur name")
print(a)

# %%
str1="i am angira and i love myself.\n my fev colour is black."
print (str1)

# %%
str1="i am angira and i love myself.\n my fev colour is black."
len(str(str1))
len(str(-6))

# %%
#slicing
str="angira"
str[1:5 ]
str[0:5]
str[0:]

# %%
#negative index
str="apple"
str[ :-5]

# %%
#functions
str="i am studing in kolkata my clg name is SNU"
print(str.endswith("snu"))

# %%
str="i am studing in kolkata my clg name is SNU"
print(str.endswith("SNU"))

# %%
str="i am studing in kolkata my clg name is SNU"
print(str.capitalize())

# %%
str="i am studing in kolkata my clg name is SNU"
print(str.replace("a","oii"))

# %%
str="i am studing in kolkata my clg name is SNU"
print(str.find("am"))

# %%
age=21
if(age>=20):
    print("you are elegable")

# %%
light="green"
if(light=="red"):
    print("stop")
elif(light=="black"):
    print("go")
print("end of code")

# %%
marks=[94.4,86,5,33,4,100,95,3]
print(marks)
print(type(marks))

# %%
marks=[87.05,99,21,33,55]
marks[1:5]

# %%
marks=[87.05,99,21,33,55]
marks[ :6]
marks[0: ]
marks[-3:-0]

# %%
list=[88,55,33,99]
list.append(155)
print(list)

# %%
marks=[87.05,99,21,33,55]
print(list.sort())
print(list)

# %%
marks=[87.05,99,21,33,55]
print(list.sort())
print(list)

# %%
marks=[87.05,99,21,33,55]
list.sort(reverse=True)
print(list)

# %%
marks=[87.05,99,21,33,55]
list.reverse()
print(list)

# %%
marks=[87.05,99,21,33,55]
list.insert(0,5)
print(list)

# %%
marks=[87.05,99,21,33,55]
list.remove(99)
print(list)
