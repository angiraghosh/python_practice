# %% [markdown]
# 1. Comment in Python

# %%
a = 10
b = 20
#I am going to add a and b - this is a single line comment
print(a + b)

# %%
name = 'abc'
age = 20
height = 160
'''This is bio-data of a person,
his name, age and height is being captured - this is a multi-line comment'''
print(name,age, height)

# %% [markdown]
# String - Concatenation, Indexing and many more...

# %%
a = 'rishikesh'
b = "haridwar"
#anything inside the single/double quotes is string
print(a)
print(b)

# %%
print(type(a))

# %%
print(type(b))

# %%
a = 10
b = '10'
print(type(a))
print(type(b))

# %%
a = 10.5
b = '10.5'
print(type(a))
print(type(b))

# %%
a = 'delhi'
print(type(a))

# %%
email = 'myname15@gmail.com'
print(type(email))

# %%
a = True
b = False
c = 'True'
d = 'False'
print(type(a))
print(type(b))
print(type(c))
print(type(d))

# %% [markdown]
# String - concatenation

# %%
firstname = 'Subhash'
middlename = 'Chandra'
lastname = 'Bose'
print(firstname+' '+middlename+' '+lastname)

# %%
a = input('Give your email id before @gmail.com')
print(a+'@gmail.com')

# %%
print('my age is'+10)

# %%
print("my age is "+'10')

# %%
firstname = input("Give your first name")
lastname = input("Give your last name")
fullname = firstname + ' ' + lastname
print(fullname)
